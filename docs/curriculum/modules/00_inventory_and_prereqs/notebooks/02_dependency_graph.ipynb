# %% [markdown]
# # Dependency graph
#
# Print the module prerequisites in the deep-study trunk.

# %%
from pathlib import Path
import json

manifest = json.loads(Path('docs/curriculum/module_manifest.json').read_text())
for module in manifest['modules']:
    prereqs = module['prerequisites'] or ['<start>']
    print(f"{module['id']} -> {', '.join(prereqs)}")

# %% [markdown]
# # HMC comparison template
#
# Template cell showing how to structure a PyMC vs Stan comparison.

# %%
comparison_plan = {
    'model': 'binomial-logit or normal-means model',
    'py_stack': ['pymc', 'arviz'],
    'stan_stack': ['cmdstanpy'],
    'diagnostics': ['r_hat', 'ess_bulk', 'ess_tail', 'divergences', 'energy'],
    'workflow_checks': ['posterior_predictive', 'loo_or_waic', 'sbc_if_custom_sampler'],
}
for key, value in comparison_plan.items():
    print(key, '=>', value)
